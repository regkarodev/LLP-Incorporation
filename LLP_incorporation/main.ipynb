# %%
# %run functions.ipynb
# Out:
# #guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_2015234307-guidedropdownlist_co___widget is not found
# #guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_2015234307-guidedropdownlist_co___widget > option:nth-child(2) is not found

# %%
#fill login credentials
send_text(css_selector="#guideContainer-rootPanel-panel_1846244155-guidetextbox___widget",keys='shagun@registerkaro.in')
time.sleep(0.5)
send_text(css_selector="#guideContainer-rootPanel-panel_1846244155-guidepasswordbox___widget",keys="SLPL@1234")

# %%
#time to fill captcha
time.sleep(10)

# %%
#login submit
click_element(css_selector="#guideContainer-rootPanel-panel_1846244155-submit___widget")

# %%
#LLP
click_element(css_selector="#guideContainer-rootPanel-panel-panel-panel-panel_copy_copy-panel1626772568950-guideradiobutton__-1_widget")

# %% [markdown]
# # LLP Details

# %%
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel-panel-panel_copy_copy-panel1626772568950-guideradiobutton__-1_widget')



send_text(css_selector='#guideContainer-rootPanel-panel-panel-panel-panel_copy_copy-panel1626772568950-guidetextbox_copy___widget', keys='M28055632')


time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel-panel-panel_copy_copy-panel1626772568950-guideradiobutton_1069538009__-1_widget')

# %% [markdown]
# ## Buttons

# %%
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel-panel-panel_copy_copy_copy-mca_button___widget')


time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-modal_container_copy-panel_86338280-panel-mca_button___widget')


time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel-panel_copy_copy_copy_1792429032-mca_button___widget')

# %%
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel-panel_702814714-panel-guidetextbox_copy_11___widget', keys='3rd')
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel-panel_702814714-panel-guidetextbox_copy_11_635080626___widget', keys='Street No 3')

send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel-panel_702814714-panel-guidetextbox_copy_11_1386963699___widget', keys='122016')


# *Area/ Locality
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel-panel_702814714-panel-guidetextbox_9527960___widget', keys='Industrial Complex Dhundahera')

# send_text(css_selector='', keys='')

# *Longitude
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel-panel_702814714-panel-guidetextbox_1045433___widget', keys='28.8881')

# *Latitude
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel-panel_702814714-panel-guidetextbox_1045433_1076286455___widget', keys='36.9999')

# *Jurisdiction of Police Station
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel-panel_702814714-panel-guidetextbox_copy___widget', keys='Gurugram')

# %% [markdown]
# #### (b) Contact Details

# %%
# Phone (with STD/ISD code)
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_417418999-panel_2000768201_cop-phonestdisdbox___widget', keys='91')

# *Mobile No.
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_417418999-panel_2000768201_cop-guidetextbox_copy_11_211671462___widget', keys='9354886960')

# Fax
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_417418999-panel_2000768201_cop-guidenumericbox_1010___widget', keys='1101234567')

# *Email ID
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_417418999-panel_2000768201_cop-guidetextbox_copy_11___widget', keys='shagun@registerkaro.in')

# %%
#(d) *Name of the office of Registrar in whose jurisdiction the proposed LLP is to be registered

send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_2015234307-guidedropdownlist_co___widget', keys='Registrar of Companies, National Capital Territory of Delhi and Haryana')

# %%
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1891907560_cop-table_copy-Row1629350115276-tableItem1629350115279___widget', keys='1')
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1891907560_cop-table_copy-Row1629350123645-tableItem1629350123648___widget', keys='1')
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1891907560_cop-table_copy-Row1629350126976-tableItem1629350126979___widget', keys='0')
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1891907560_cop-table_copy-Row1629350131849-tableItem1629350131852___widget', keys='0')
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1891907560_cop-table_copy-Row1629350148437-tableItem1629350148441___widget', keys='0')
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1891907560_cop-table_copy-Row1629356006750-tableItem1629356006753___widget', keys='0')
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1891907560_cop-table_copy-Row1629356019361-tableItem1629356019364___widget', keys='0')
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1891907560_cop-table_copy-Row1629356041275-tableItem1629356041278___widget', keys='0')

# %%
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel_1068208772-panel-guidetextbox_copy_co___widget', keys='10290759')


time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel_1068208772-panel-guideradiobutton_cop__-1_widget')

# Form of contribution
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel_1068208772-panel_1190620866-guidedropdownlist___widget', keys='Cash')


send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel_1068208772-panel_1190620866-guidetextbox_copy___widget', keys='100000000')


send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel_1068208772-panel_1190620866-guidetextbox_copy_1389782663___widget', keys='Ten crore')


send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel_1068208772-panel_1190620866-guidetextbox_copy_16___widget', keys='2')


send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel_1068208772-panel_1190620866-guidetextbox_copy_70___widget', keys='4')

# %%
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guidetextbox_copy_11___widget', keys='Ashish')
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guidetextbox_copy_11_1103730967___widget', keys='Singh')
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guidetextbox_copy_11_1562614891___widget', keys='Mehra')


# Father's First Name
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guidetextbox_copy_11_2008497050___widget', keys='Chanchal')

# Father's Middle Name
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guidetextbox_copy_11_97181591___widget', keys='SIngh')

# Father's Surname
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guidetextbox_copy_11_489985667___widget', keys='Mehra')


# Gender
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guidetextbox_copy_11_1126939658___widget', keys='Male')

# %%
import time
import traceback
from selenium.webdriver.common.by import By

# %%
def log_terminal_output(message, level="info"):
    timestamp = time.strftime("%Y-%m-%d %H:%M:%S")
    print(f"[{timestamp}] [{level.upper()}] {message}")


def fill_dob(driver):
    """Fill Date of Birth section"""
    try:
        log_terminal_output("\n=== Filling Date of Birth Section ===")
        log_terminal_output("Starting streamlined DOB selection...")
        time.sleep(2)
        
        dob_value_to_use = '19/06/2001'
        log_terminal_output(f"Target date: {dob_value_to_use}")
        
        dob_xpaths = [
            '//*[@id="guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guidedatepicker___widget"]',
            '//input[contains(@id, "guidedatepicker")]',
            '//input[@type="text" and contains(@class, "datepicker")]',
            '//input[contains(@class, "date")]'
        ]

        try:
            screenshot_path = f"before_dob_fill_{int(time.time())}.png"
            driver.save_screenshot(screenshot_path)
            log_terminal_output(f"Screenshot saved before filling DOB: {screenshot_path}")
        except:
            pass

        driver.switch_to.default_content()

        iframes = driver.find_elements(By.TAG_NAME, "iframe")
        log_terminal_output(f"Found {len(iframes)} iframes on the page")

        dob_input = None
        for xpath in dob_xpaths:
            try:
                elements = driver.find_elements(By.XPATH, xpath)
                for element in elements:
                    if element.is_displayed():
                        dob_input = element
                        log_terminal_output(f"Found DOB input field using XPath: {xpath}")
                        break
                if dob_input:
                    break
            except:
                continue

        if not dob_input:
            log_terminal_output("Could not find DOB input field, trying iframes...")
            for iframe in iframes:
                try:
                    driver.switch_to.frame(iframe)
                    for xpath in dob_xpaths:
                        try:
                            elements = driver.find_elements(By.XPATH, xpath)
                            for element in elements:
                                if element.is_displayed():
                                    dob_input = element
                                    log_terminal_output(f"Found DOB input field in iframe using XPath: {xpath}")
                                    break
                            if dob_input:
                                break
                        except:
                            continue
                    if dob_input:
                        break
                except:
                    continue
                finally:
                    driver.switch_to.default_content()

        if not dob_input:
            log_terminal_output("Could not find DOB input field anywhere", "error")
            return False

        driver.execute_script("arguments[0].scrollIntoView({block: 'center'});", dob_input)
        time.sleep(1)

        # Set value directly
        dob_input.clear()
        dob_input.send_keys(dob_value_to_use)
        log_terminal_output("Set date using direct input")
        time.sleep(1)

        # JavaScript fallback
        driver.execute_script(f"""
            arguments[0].value = '{dob_value_to_use}';
            arguments[0].dispatchEvent(new Event('input', {{ 'bubbles': true }}));
            arguments[0].dispatchEvent(new Event('change', {{ 'bubbles': true }}));
        """, dob_input)
        log_terminal_output("Set date using JavaScript")
        time.sleep(1)

        # Verify value set correctly before trying calendar
        actual_value = dob_input.get_attribute('value')
        if actual_value == dob_value_to_use:
            log_terminal_output("Successfully verified date was set correctly")
        else:
            log_terminal_output(f"Warning: Expected DOB '{dob_value_to_use}', but got '{actual_value}'")

        # Optional calendar interaction if value not set
        if actual_value != dob_value_to_use:
            try:
                calendar_icon = driver.execute_script("""
                    var input = arguments[0];
                    var parent = input.parentElement;
                    var calendarIcon = null;
                    while (parent && !calendarIcon) {
                        var imgs = parent.querySelectorAll('img');
                        for (var i = 0; i < imgs.length; i++) {
                            if (imgs[i].offsetWidth > 0 && imgs[i].offsetHeight > 0) {
                                calendarIcon = imgs[i];
                                break;
                            }
                        }
                        parent = parent.parentElement;
                    }
                    return calendarIcon;
                """, dob_input)

                if calendar_icon:
                    calendar_icon.click()
                    log_terminal_output("Clicked calendar icon")
                    time.sleep(1)

                    day, month, year = dob_value_to_use.split('/')
                    date_xpath = f"//td[contains(@class, 'day') and text()='{day}']"
                    try:
                        date_element = driver.find_element(By.XPATH, date_xpath)
                        date_element.click()
                        log_terminal_output("Clicked date in calendar")
                    except:
                        log_terminal_output("Could not click date in calendar")
            except:
                log_terminal_output("Could not interact with calendar")

        try:
            screenshot_path = f"after_dob_set_{int(time.time())}.png"
            driver.save_screenshot(screenshot_path)
            log_terminal_output(f"Screenshot saved after setting DOB: {screenshot_path}")
        except:
            pass

        return True

    except Exception as e:
        log_terminal_output(f"Error in fill_dob: {str(e)}", "error")
        log_terminal_output(traceback.format_exc(), "error")
        return False

# %%
fill_dob(driver)
# Out:
# [2025-05-20 18:12:38] [INFO]
# === Filling Date of Birth Section ===
# [2025-05-20 18:12:38] [INFO] Starting streamlined DOB selection...
# [2025-05-20 18:12:40] [INFO] Target date: 19/06/2001
# [2025-05-20 18:12:40] [INFO] Screenshot saved before filling DOB: before_dob_fill_1747744960.png
# [2025-05-20 18:12:40] [INFO] Found 23 iframes on the page
# [2025-05-20 18:12:40] [INFO] Found DOB input field using XPath: //*[@id="guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guidedatepicker___widget"]
# [2025-05-20 18:12:42] [INFO] Set date using direct input
# [2025-05-20 18:12:43] [INFO] Set date using JavaScript
# [2025-05-20 18:12:44] [INFO] Successfully verified date was set correctly
# [2025-05-20 18:12:44] [INFO] Screenshot saved after setting DOB: after_dob_set_1747744964.png
# True

# %%
# Nationality
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guidetextbox_copy_11_905293595___widget')
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guidetextbox_copy_11_905293595___widget > option:nth-child(102)')

# %%
# Whether resident of India
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guidecheckbox_copy_c_1044176976__-1_widget')

# %%
# Income-tax PAN/Passport number
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guideradiobutton_290__-1_widget')

# %%
# Income-tax PAN/Passport number details
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-panel_130595931_copy-guidetextbox_copy_11___widget', keys='GVBPM4605P')


time.sleep(3)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-panel_130595931_copy-mca_button___widget')

# %%
# Place of Birth (State)
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guidetextbox_copy_11_1516867585___widget')
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guidetextbox_copy_11_1516867585___widget > option:nth-child(11)')

# Place of Birth (District)
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guidetextbox_copy_11_1713202154___widget')
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guidetextbox_copy_11_1713202154___widget > option:nth-child(603)')

# %%
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guidecheckbox_copy_c__-1_widget')

# %%
# Occupation type
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guidetextbox_copy_11_2129385629___widget')
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guidetextbox_copy_11_2129385629___widget > option:nth-child(4)')


# Area of Occupation
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guidetextbox_copy_11_1003108991___widget')
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guidetextbox_copy_11_1003108991___widget > option:nth-child(5)')



# Educational qualification
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guidetextbox_copy_11_164495912___widget')
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guidetextbox_copy_11_164495912___widget > option:nth-child(5)')

# %%
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guidetelephone_copy___widget', keys='9354886960')
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_406391466-guidetextbox_2056351___widget', keys='ashishmehra@registerkaro.com')

# %%
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_1161909677-guidetextbox___widget', keys='Unitech Signature Tower-II')
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_1161909677-guidetextbox_copy___widget', keys=' Tower A, South City 1')


# Country
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_1161909677-guidedropdownlist___widget')
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_1161909677-guidedropdownlist___widget > option:nth-child(102)')


# Pin code / Zip Code
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_1161909677-guidetextbox_copy_1737891757___widget', keys='122001')

# Area/ Locality
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_1161909677-guidedropdownlist_1592911853___widget')
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_1161909677-guidedropdownlist_1592911853___widget > option:nth-child(10)')


# Jurisdiction of Police Station
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_1161909677-guidetextbox_1308366___widget', keys='Sector 30')

# Phone (with STD/ISD code)
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_1161909677-guidetextbox_copy_165380706___widget', keys='91')

# %%
# Whether present residential address same as permanent residential address
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_1161909677-guideradiobutton__-1_widget')

# %%
# Identity Proof
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_1688891306-guidedropdownlist___widget', keys='Aadhaar')

# Residential Proof
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_1688891306-guidedropdownlist_54267595___widget', keys='Electricity Bill')

# Identity Proof No.
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_1688891306-guidetextbox___widget', keys='826851933417')

# Residential Proof No.
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_1688891306-guidetextbox_1665947846___widget', keys='QUT030055A0AA')

# %% [markdown]
# ### Upload

# %%
# Out:
# [2025-05-20 17:29:11] [INFO]
# === Starting Automatic File Upload Process ===
# [2025-05-20 17:29:11] [INFO] Normalized file path: C:\Users\Admin\Downloads\dummypdf.pdf
# [2025-05-20 17:29:11] [INFO] Screenshot saved before upload: before_upload_click_1747742351.png
# [2025-05-20 17:29:13] [INFO] Clicked button directly
# [2025-05-20 17:29:15] [INFO] Found file input using CSS selector: input[type='file']
# [2025-05-20 17:29:15] [INFO] File path sent to input using send_keys
# [2025-05-20 17:29:15] [INFO] Screenshot saved after upload: after_upload_1747742355.png
# [2025-05-20 17:29:17] [WARNING] Warning: File path verification failed. Expected: C:\Users\Admin\Downloads\dummypdf.pdf, Got: C:\fakepath\dummypdf.pdf
# File upload failed!

# %%
# Out:
# [2025-05-20 17:29:27] [INFO]
# === Starting Automatic File Upload Process (XPath) ===
# [2025-05-20 17:29:27] [INFO] Normalized file path: C:\Users\Admin\Downloads\Letter.pdf
# [2025-05-20 17:29:27] [INFO] Screenshot saved before upload: before_upload_click_xpath_1747742367.png
# [2025-05-20 17:29:29] [INFO] Clicked button directly
# [2025-05-20 17:29:31] [INFO] Found file input using XPath: //input[@type='file']
# [2025-05-20 17:29:31] [INFO] File path sent to input using send_keys
# [2025-05-20 17:29:31] [INFO] Screenshot saved after upload: after_upload_xpath_1747742371.png
# [2025-05-20 17:29:33] [INFO] Successfully verified file upload
# File uploaded successfully!

# %%
# Form of contribution
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel_1068208772-panel_1190620866-guidedropdownlist___widget', keys='Cash')


# Monetary value of contribution (in INR.) (in figures)
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_254891280-guidetextbox_copy___widget', keys='200')


# Number of LLP(s) in which he/ she is a partner
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_254891280-guidetextbox_copy_1389782663___widget', keys='two hundred')

# Number of LLP(s) in which he/ she is a partner
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_254891280-guidetextbox_copy_1672616692___widget', keys='2')

# Number of company(s) in which he/ she is a director
send_text(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_1228427250-panel-panel-panel_254891280-guidetextbox_copy_709870004___widget',keys='2')

# %%
# SAVE BUTTON
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel_copy_copy_copy-mca_button_copy___widget')

# POPUP - OK BUTTON
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-modal_container_copy-panel_86338280-panel-mca_button___widget')

# NEXT BUTTON
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel_copy_copy_copy-mca_button___widget')

# %% [markdown]
# ### PAN/ TAN Information

# %%
# *Area code
send_text(css_selector='#guideContainer-rootPanel-panel-panel_358466187-panel-panel_copy_copy-panel-panel_copy-panel_969275493-panel-guidetextbox___widget', keys='N')


send_text(css_selector='#guideContainer-rootPanel-panel-panel_358466187-panel-panel_copy_copy-panel-panel_copy-panel_969275493-panel-guidetextbox_copy___widget', keys='W')


send_text(css_selector='#guideContainer-rootPanel-panel-panel_358466187-panel-panel_copy_copy-panel-panel_copy-panel_969275493-panel-guidetextbox_copy_2031803169___widget', keys='R')


# *AO type
send_text(css_selector='#guideContainer-rootPanel-panel-panel_358466187-panel-panel_copy_copy-panel-panel_copy-panel_969275493-panel_copy_912586437-guidetextbox___widget', keys='W')


# *Range code

send_text(css_selector='#guideContainer-rootPanel-panel-panel_358466187-panel-panel_copy_copy-panel-panel_copy-panel_969275493-panel_copy_450718701-guidetextbox___widget', keys='5')

send_text(css_selector='#guideContainer-rootPanel-panel-panel_358466187-panel-panel_copy_copy-panel-panel_copy-panel_969275493-panel_copy_450718701-guidetextbox_copy___widget', keys='3')


# *AO No.
send_text(css_selector='#guideContainer-rootPanel-panel-panel_358466187-panel-panel_copy_copy-panel-panel_copy-panel_969275493-panel_copy_912586437_1323045745-guidetextbox___widget', keys='3')

# %% [markdown]
# ##### Information specific to TAN

# %%
# *Area code
send_text(css_selector='#guideContainer-rootPanel-panel-panel_358466187-panel-panel_copy_copy-panel-panel_copy-panel_copy-panel_969275493_copy-panel-guidetextbox___widget', keys='N')


send_text(css_selector='#guideContainer-rootPanel-panel-panel_358466187-panel-panel_copy_copy-panel-panel_copy-panel_copy-panel_969275493_copy-panel-guidetextbox_copy___widget', keys='W')


send_text(css_selector='#guideContainer-rootPanel-panel-panel_358466187-panel-panel_copy_copy-panel-panel_copy-panel_copy-panel_969275493_copy-panel-guidetextbox_copy_2031803169___widget', keys='R')

# *AO type
send_text(css_selector='#guideContainer-rootPanel-panel-panel_358466187-panel-panel_copy_copy-panel-panel_copy-panel_copy-panel_969275493_copy-panel_copy_912586437-guidetextbox___widget', keys='W')

send_text(css_selector='#guideContainer-rootPanel-panel-panel_358466187-panel-panel_copy_copy-panel-panel_copy-panel_copy-panel_969275493_copy-panel_copy_912586437-guidetextbox_copy___widget', keys='T')

# *Range code
send_text(css_selector='#guideContainer-rootPanel-panel-panel_358466187-panel-panel_copy_copy-panel-panel_copy-panel_copy-panel_969275493_copy-panel_copy_450718701-guidetextbox___widget', keys='7')

send_text(css_selector='#guideContainer-rootPanel-panel-panel_358466187-panel-panel_copy_copy-panel-panel_copy-panel_copy-panel_969275493_copy-panel_copy_450718701-guidetextbox_copy___widget', keys='4')

send_text(css_selector='#guideContainer-rootPanel-panel-panel_358466187-panel-panel_copy_copy-panel-panel_copy-panel_copy-panel_969275493_copy-panel_copy_450718701-guidetextbox_copy___widget', keys='7')


# *AO No.
send_text(css_selector='#guideContainer-rootPanel-panel-panel_358466187-panel-panel_copy_copy-panel-panel_copy-panel_copy-panel_969275493_copy-panel_copy_912586437_1323045745-guidetextbox___widget', keys='2')

# %%
# click_element(css_selector='#guideContainer-rootPanel-panel-panel_358466187-panel-panel_copy_copy-panel-panel_copy-panel_copy-panel_969275493_copy-guidetextbox_2064455___widget')
time.sleep(2)
send_text(css_selector='#guideContainer-rootPanel-panel-panel_358466187-panel-panel_copy_copy-panel-panel_copy-panel_copy-panel_969275493_copy-guidetextbox_2064455___widget > option:nth-child(6)', keys='Capital Gain')

# %%
# SAVE BUTTON
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_358466187-panel-panel_copy_copy_copy-mca_button_copy___widget')

# POPUP - OK BUTTON
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-modal_container_copy_1296064375-panel_86338280-panel-mca_button___widget')

# NEXT BUTTON
time.sleep(2)
click_element(css_selector='#guideContainer-rootPanel-panel-panel_358466187-panel-panel_copy_copy_copy-mca_button___widget')
# Out:
# #guideContainer-rootPanel-modal_container_copy_1296064375-panel_86338280-panel-mca_button___widget is not found

# %%
def auto_upload_file(driver, button_css_selector, file_path):
    """Automatically click the Choose File button and upload a document.
    
    Args:
        driver: Selenium WebDriver instance
        button_css_selector: CSS selector for the Choose File button
        file_path: Path to the file to upload
        
    Returns:
        bool: True if upload was successful, False otherwise
    """
    try:
        log_terminal_output("\n=== Starting Automatic File Upload Process ===")
        
        # Validate inputs
        if not driver:
            log_terminal_output("Error: WebDriver instance is required", "error")
            return False
            
        if not button_css_selector:
            log_terminal_output("Error: Button CSS selector is required", "error")
            return False
            
        if not file_path:
            log_terminal_output("Error: File path is required", "error")
            return False
            
        # Normalize file path
        try:
            if '\\' in file_path:
                file_path = file_path.replace('\\', '/')
            abs_file_path = os.path.abspath(file_path)
            log_terminal_output(f"Normalized file path: {abs_file_path}")
        except Exception as e:
            log_terminal_output(f"Error normalizing file path: {str(e)}", "error")
            return False
            
        # Verify file exists
        if not os.path.exists(abs_file_path):
            log_terminal_output(f"Error: File not found at path: {abs_file_path}", "error")
            return False
            
        # Take screenshot before starting
        try:
            screenshot_path = f"before_upload_click_{int(time.time())}.png"
            driver.save_screenshot(screenshot_path)
            log_terminal_output(f"Screenshot saved before upload: {screenshot_path}")
        except Exception as e:
            log_terminal_output(f"Warning: Could not take screenshot: {str(e)}", "warning")
            
        # Find and click the Choose File button
        try:
            # Wait for button to be present and clickable
            button = WebDriverWait(driver, 10).until(
                EC.element_to_be_clickable((By.CSS_SELECTOR, button_css_selector))
            )
            
            # Scroll button into view
            driver.execute_script("arguments[0].scrollIntoView({block: 'center'});", button)
            time.sleep(1)
            
            # Try multiple click methods
            click_success = False
            
            # Method 1: Direct click
            try:
                button.click()
                log_terminal_output("Clicked button directly")
                click_success = True
            except Exception as e:
                log_terminal_output(f"Direct click failed: {str(e)}", "warning")
                
            # Method 2: JavaScript click
            if not click_success:
                try:
                    driver.execute_script("arguments[0].click();", button)
                    log_terminal_output("Clicked button using JavaScript")
                    click_success = True
                except Exception as e:
                    log_terminal_output(f"JavaScript click failed: {str(e)}", "warning")
                    
            # Method 3: ActionChains
            if not click_success:
                try:
                    from selenium.webdriver.common.action_chains import ActionChains
                    actions = ActionChains(driver)
                    actions.move_to_element(button).click().perform()
                    log_terminal_output("Clicked button using ActionChains")
                    click_success = True
                except Exception as e:
                    log_terminal_output(f"ActionChains click failed: {str(e)}", "warning")
            
            if not click_success:
                log_terminal_output("Error: Could not click the Choose File button", "error")
                return False
                
            # Wait for file input to appear
            time.sleep(2)  # Increased wait time
            
            # Find the file input element that appears after clicking
            try:
                # Try different selectors for the file input
                file_input_selectors = [
                    "input[type='file']",
                    "input[accept*='pdf']",
                    "input[accept*='document']",
                    "input.file-upload",
                    "input.upload-input",
                    "input[class*='file']",
                    "input[class*='upload']",
                    "input[style*='display: none']",  # Hidden file inputs
                    "input[style*='display:none']",
                    "input[type='file'][style*='display: none']",
                    "input[type='file'][style*='display:none']"
                ]
                
                # Also try finding by XPath
                xpath_selectors = [
                    "//input[@type='file']",
                    "//input[contains(@class, 'file')]",
                    "//input[contains(@class, 'upload')]",
                    "//input[contains(@style, 'display: none')]",
                    "//input[contains(@style, 'display:none')]"
                ]
                
                file_input = None
                
                # First try CSS selectors
                for selector in file_input_selectors:
                    try:
                        elements = driver.find_elements(By.CSS_SELECTOR, selector)
                        for element in elements:
                            # Check if element is present in DOM
                            if element.is_enabled():
                                file_input = element
                                log_terminal_output(f"Found file input using CSS selector: {selector}")
                                break
                        if file_input:
                            break
                    except Exception as e:
                        log_terminal_output(f"Warning: CSS selector {selector} failed: {str(e)}", "warning")
                        continue
                
                # If not found, try XPath selectors
                if not file_input:
                    for xpath in xpath_selectors:
                        try:
                            elements = driver.find_elements(By.XPATH, xpath)
                            for element in elements:
                                if element.is_enabled():
                                    file_input = element
                                    log_terminal_output(f"Found file input using XPath: {xpath}")
                                    break
                            if file_input:
                                break
                        except Exception as e:
                            log_terminal_output(f"Warning: XPath {xpath} failed: {str(e)}", "warning")
                            continue
                
                # If still not found, try JavaScript to find hidden inputs
                if not file_input:
                    try:
                        file_input = driver.execute_script("""
                            return document.querySelector('input[type="file"]') || 
                                   document.querySelector('input[accept*="pdf"]') ||
                                   document.querySelector('input[class*="file"]') ||
                                   document.querySelector('input[class*="upload"]');
                        """)
                        if file_input:
                            log_terminal_output("Found file input using JavaScript")
                    except Exception as e:
                        log_terminal_output(f"Warning: JavaScript file input search failed: {str(e)}", "warning")
                
                if not file_input:
                    log_terminal_output("Error: Could not find file input element", "error")
                    return False
                    
                # Send file path to input
                try:
                    # Try direct send_keys first
                    file_input.send_keys(abs_file_path)
                    log_terminal_output("File path sent to input using send_keys")
                except Exception as e:
                    log_terminal_output(f"Warning: Direct send_keys failed: {str(e)}", "warning")
                    try:
                        # Try JavaScript as fallback
                        driver.execute_script("""
                            arguments[0].value = arguments[1];
                            arguments[0].dispatchEvent(new Event('change', { 'bubbles': true }));
                        """, file_input, abs_file_path)
                        log_terminal_output("File path sent to input using JavaScript")
                    except Exception as e:
                        log_terminal_output(f"Error: Could not send file path to input: {str(e)}", "error")
                        return False
                
                # Take screenshot after upload
                try:
                    screenshot_path = f"after_upload_{int(time.time())}.png"
                    driver.save_screenshot(screenshot_path)
                    log_terminal_output(f"Screenshot saved after upload: {screenshot_path}")
                except Exception as e:
                    log_terminal_output(f"Warning: Could not take screenshot: {str(e)}", "warning")
                
                # Wait for upload to complete
                time.sleep(2)
                
                # Verify upload
                try:
                    # Check if file input has the file path
                    actual_value = file_input.get_attribute('value')
                    if abs_file_path in actual_value:
                        log_terminal_output("Successfully verified file upload")
                        return True
                    else:
                        log_terminal_output(f"Warning: File path verification failed. Expected: {abs_file_path}, Got: {actual_value}", "warning")
                        return False
                except Exception as e:
                    log_terminal_output(f"Warning: Could not verify upload: {str(e)}", "warning")
                    return False
                    
            except Exception as e:
                log_terminal_output(f"Error handling file input: {str(e)}", "error")
                return False
                
        except Exception as e:
            log_terminal_output(f"Error finding or clicking button: {str(e)}", "error")
            return False
            
    except Exception as e:
        log_terminal_output(f"Error in auto_upload_file: {str(e)}", "error")
        log_terminal_output(traceback.format_exc(), "error")
        return False

# %%
button_css_selector = '#guideContainer-rootPanel-panel-panel_1815470267-panel_1379931518_cop-panel-panel_copy-fileuploadwithplaceh__ > div:nth-child(3) > div:nth-child(1) > button:nth-child(3)'
file_path = "C:\\Users\\Admin\\Downloads\\dummypdf.pdf"  # Use forward slashes

success = auto_upload_file(driver, button_css_selector, file_path)
if success:
    print("File uploaded successfully!")
else:
    print("File upload failed!")

# %%
def auto_upload_file_xpath(driver, button_xpath, file_path):
    """Automatically click the Choose File button and upload a document using XPath.
    
    Args:
        driver: Selenium WebDriver instance
        button_xpath: XPath for the Choose File button
        file_path: Path to the file to upload
        
    Returns:
        bool: True if upload was successful, False otherwise
    """
    try:
        log_terminal_output("\n=== Starting Automatic File Upload Process (XPath) ===")
        
        # Validate inputs
        if not driver:
            log_terminal_output("Error: WebDriver instance is required", "error")
            return False
            
        if not button_xpath:
            log_terminal_output("Error: Button XPath is required", "error")
            return False
            
        if not file_path:
            log_terminal_output("Error: File path is required", "error")
            return False
            
        # Normalize file path
        try:
            if '\\' in file_path:
                file_path = file_path.replace('\\', '/')
            abs_file_path = os.path.abspath(file_path)
            log_terminal_output(f"Normalized file path: {abs_file_path}")
        except Exception as e:
            log_terminal_output(f"Error normalizing file path: {str(e)}", "error")
            return False
            
        # Verify file exists
        if not os.path.exists(abs_file_path):
            log_terminal_output(f"Error: File not found at path: {abs_file_path}", "error")
            return False
            
        # Take screenshot before starting
        try:
            screenshot_path = f"before_upload_click_xpath_{int(time.time())}.png"
            driver.save_screenshot(screenshot_path)
            log_terminal_output(f"Screenshot saved before upload: {screenshot_path}")
        except Exception as e:
            log_terminal_output(f"Warning: Could not take screenshot: {str(e)}", "warning")
            
        # Find and click the Choose File button
        try:
            # Wait for button to be present and clickable
            button = WebDriverWait(driver, 10).until(
                EC.element_to_be_clickable((By.XPATH, button_xpath))
            )
            
            # Scroll button into view
            driver.execute_script("arguments[0].scrollIntoView({block: 'center'});", button)
            time.sleep(1)
            
            # Try multiple click methods
            click_success = False
            
            # Method 1: Direct click
            try:
                button.click()
                log_terminal_output("Clicked button directly")
                click_success = True
            except Exception as e:
                log_terminal_output(f"Direct click failed: {str(e)}", "warning")
                
            # Method 2: JavaScript click
            if not click_success:
                try:
                    driver.execute_script("arguments[0].click();", button)
                    log_terminal_output("Clicked button using JavaScript")
                    click_success = True
                except Exception as e:
                    log_terminal_output(f"JavaScript click failed: {str(e)}", "warning")
                    
            # Method 3: ActionChains
            if not click_success:
                try:
                    from selenium.webdriver.common.action_chains import ActionChains
                    actions = ActionChains(driver)
                    actions.move_to_element(button).click().perform()
                    log_terminal_output("Clicked button using ActionChains")
                    click_success = True
                except Exception as e:
                    log_terminal_output(f"ActionChains click failed: {str(e)}", "warning")
            
            if not click_success:
                log_terminal_output("Error: Could not click the Choose File button", "error")
                return False
                
            # Wait for file input to appear
            time.sleep(2)  # Increased wait time
            
            # Find the file input element that appears after clicking
            try:
                # Try different XPath patterns for the file input
                xpath_patterns = [
                    "//input[@type='file']",
                    "//input[contains(@class, 'file')]",
                    "//input[contains(@class, 'upload')]",
                    "//input[contains(@style, 'display: none')]",
                    "//input[contains(@style, 'display:none')]",
                    "//input[contains(@accept, 'pdf')]",
                    "//input[contains(@accept, 'document')]",
                    "//input[contains(@id, 'file')]",
                    "//input[contains(@id, 'upload')]",
                    "//input[contains(@name, 'file')]",
                    "//input[contains(@name, 'upload')]"
                ]
                
                file_input = None
                
                # Try each XPath pattern
                for xpath in xpath_patterns:
                    try:
                        elements = driver.find_elements(By.XPATH, xpath)
                        for element in elements:
                            if element.is_enabled():
                                file_input = element
                                log_terminal_output(f"Found file input using XPath: {xpath}")
                                break
                        if file_input:
                            break
                    except Exception as e:
                        log_terminal_output(f"Warning: XPath {xpath} failed: {str(e)}", "warning")
                        continue
                
                # If not found, try JavaScript to find hidden inputs
                if not file_input:
                    try:
                        file_input = driver.execute_script("""
                            return document.querySelector('input[type="file"]') || 
                                   document.querySelector('input[accept*="pdf"]') ||
                                   document.querySelector('input[class*="file"]') ||
                                   document.querySelector('input[class*="upload"]');
                        """)
                        if file_input:
                            log_terminal_output("Found file input using JavaScript")
                    except Exception as e:
                        log_terminal_output(f"Warning: JavaScript file input search failed: {str(e)}", "warning")
                
                if not file_input:
                    log_terminal_output("Error: Could not find file input element", "error")
                    return False
                    
                # Send file path to input
                try:
                    # Try direct send_keys first
                    file_input.send_keys(abs_file_path)
                    log_terminal_output("File path sent to input using send_keys")
                except Exception as e:
                    log_terminal_output(f"Warning: Direct send_keys failed: {str(e)}", "warning")
                    try:
                        # Try JavaScript as fallback
                        driver.execute_script("""
                            arguments[0].value = arguments[1];
                            arguments[0].dispatchEvent(new Event('change', { 'bubbles': true }));
                        """, file_input, abs_file_path)
                        log_terminal_output("File path sent to input using JavaScript")
                    except Exception as e:
                        log_terminal_output(f"Error: Could not send file path to input: {str(e)}", "error")
                        return False
                
                # Take screenshot after upload
                try:
                    screenshot_path = f"after_upload_xpath_{int(time.time())}.png"
                    driver.save_screenshot(screenshot_path)
                    log_terminal_output(f"Screenshot saved after upload: {screenshot_path}")
                except Exception as e:
                    log_terminal_output(f"Warning: Could not take screenshot: {str(e)}", "warning")
                
                # Wait for upload to complete
                time.sleep(2)
                
                # Verify upload
                try:
                    # Check if file input has the file path
                    actual_value = file_input.get_attribute('value')
                    
                    # Get just the filename from both paths
                    expected_filename = os.path.basename(abs_file_path)
                    actual_filename = os.path.basename(actual_value)
                    
                    # Check if the filenames match (ignoring the fakepath)
                    if expected_filename == actual_filename:
                        log_terminal_output("Successfully verified file upload")
                        return True
                    else:
                        log_terminal_output(f"Warning: File name verification failed. Expected: {expected_filename}, Got: {actual_filename}", "warning")
                        return False
                except Exception as e:
                    log_terminal_output(f"Warning: Could not verify upload: {str(e)}", "warning")
                    return False
                    
            except Exception as e:
                log_terminal_output(f"Error handling file input: {str(e)}", "error")
                return False
                
        except Exception as e:
            log_terminal_output(f"Error finding or clicking button: {str(e)}", "error")
            return False
            
    except Exception as e:
        log_terminal_output(f"Error in auto_upload_file_xpath: {str(e)}", "error")
        log_terminal_output(traceback.format_exc(), "error")
        return False

# %%
button_xpath = '/html/body/div[2]/div/div/div/div/div/form/div[4]/div/div[2]/div/div/div[1]/div/div[6]/div/div/div/div[1]/div/div[4]/div/div/div/div[1]/div/div[2]/div/div/div/div[1]/div/div[2]/div/div/div/div[1]/div/div[9]/div/div/div/div[1]/div/div[3]/div/div/div[2]/div[1]/button'
file_path = "C:\\Users\\Admin\\Downloads\\Letter.pdf"  # Use forward slashes

success = auto_upload_file_xpath(driver, button_xpath, file_path)
if success:
    print("File uploaded successfully!")
else:
    print("File upload failed!")
